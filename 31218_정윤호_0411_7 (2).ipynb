# %% [markdown]
# 31218_정윤호_0411_7

# %% [markdown]
# # 6021
# ![image.png](attachment:image.png)

# %%
a = input()

print(a[0])
print(a[1])
print(a[2])
print(a[3])
print(a[4])
# Out:
# Hello
# H
# e
# l
# l
# o

# %% [markdown]
# # 6022
# ![image.png](attachment:image.png)

# %%
a = input()
print(a[:2])
print(a[2:4])
print(a[-2:])
# Out:
# 200304
# 20
# 03
# 04

# %% [markdown]
# # 6023
# ![image.png](attachment:image.png)

# %%
a, b, c = input().split(':')

print(b)
# Out:
# 17:23:57
# 23

# %% [markdown]
# # 6024
# ![image.png](attachment:image.png)

# %%
a1, a2 = input().split()
s = a1 + a2
print(s)
# Out:
# hello world
# helloworld

# %% [markdown]
# # 6025
# ![image.png](attachment:image.png)

# %%
a,b=input().split()
a=int(a)
b=int(b)
print(a+b)
# Out:
# 123 -123
# 0
